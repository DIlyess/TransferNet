# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %cd ..
from src.temporalAnalysis import (
    create_digraph_for_year,
    analyze_transfer_network,
    print_network_report,
)
from src.edge_pred import TransferGraphDataProcessor
from src.data_processing import DataProcessing
import networkx as nx

# %cd notebooks
# Out:
# /Users/matthieuneau/Desktop/Centrale/MLNS/TransferNet
# /Users/matthieuneau/Desktop/Centrale/MLNS/TransferNet/notebooks

# %%
# G = create_digraph_for_year(2020)
# metrics = analyze_transfer_network(G, 2020)

for year in range(2009, 2022):
    G = create_digraph_for_year(year)
    metrics = analyze_transfer_network(G, year)

# %%
metrics
# Out:
# {'basic': {'nodes': 1082,
#   'edges': 3457,
#   'density': 0.0029556052193748174,
#   'is_strongly_connected': False,
#   'number_strongly_connected_components': 597,
#   'is_weakly_connected': True,
#   'number_weakly_connected_components': 1},
#  'connectivity': {'largest_wcc_size': 1082,
#   'largest_wcc_percentage': 100.0,
#   'largest_scc_size': 486,
#   'largest_scc_percentage': 44.91682070240296},
#  'degree': {'max_in_degree': 42,
#   'min_in_degree': 0,
#   'avg_in_degree': np.float64(3.1950092421441774),
#   'median_in_degree': np.float64(1.0),
#   'max_out_degree': 44,
#   'min_out_degree': 0,
#   'avg_out_degree': np.float64(3.1950092421441774),
#   'median_out_degree': np.float64(1.0)},
#  'top_teams': {'top_buyers': [('Retired', 42),
#    ('Vitória Guimarães SC', 27),
#    ('Chelsea FC', 26),
#    ('Moreirense FC', 26),
#    ('AS Monaco', 25),
#    ('FC Famalicão', 25),
#    ('ADO Den Haag', 25),
#    ('Gil Vicente FC', 24),
#    ('Cádiz CF', 24),
# ...
